# %% [markdown]
# **Palindrome or Not**

# %%
def is_palindrome(s):
    s = s.lower()
    return s == s[::-1]

input_string = input("Enter a string: ")

if is_palindrome(input_string):
    print(f"'{input_string}' is a palindrome.")
else:
    print(f"'{input_string}' is not a palindrome.")
# Out:
# Enter a string: 454
# '454' is a palindrome.

# %% [markdown]
# **To check whether the given number is prime number or not,if not check whether it is divisible by 3,7,9,11**

# %%
number_to_check = int(input("Enter a number: "))
check_divisibility(number_to_check)
print("divisible")
# Out:
# Enter a number: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c0164bd3cf5b> in <cell line: 2>()
#       1 number_to_check = int(input("Enter a number: "))
# ----> 2 check_divisibility(number_to_check)
#       3 print("divisible")
#
# NameError: name 'check_divisibility' is not defined
