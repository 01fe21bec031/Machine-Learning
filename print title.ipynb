# %% [markdown]
# # **my first program**

# %%
print("i am supriya")
# Out:
# i am supriya

# %%
a+b

# %% [markdown]
# variable decalartion in python
#
# Rule1:Variable should always start with alphabet or underscore
# Rule2:Variables should not start with some numbers or special characters Ex:1stnum=10
# Rule3:Variaable decalartion is case sensitive
# Name name NamE
# Name=90
# NamE=70

# %%
a=10
b=10
sum=a+b
print(sum)
print("sum")
# Out:
# 20
# sum

# %%
a=4
b=5
sum=a-b
print(sum)
# Out:
# -1

# %% [markdown]
# **variable decalaration in python**

# %%
a=5
b=4
diff=a-b
print(diff)
print("diff")
# Out:
# 1
# diff

# %% [markdown]
# diff=a-b-c

# %% [markdown]
# variable decalartion in python

# %%
a=10
b=3
c=2
diff=a-b-c
print(diff)
# Out:
# 5

# %%
mul=a*b

# %% [markdown]
# **variable decalaration in python**

# %%
a=10
b=20
mul=a*b
print(mul)
# Out:
# 200

# %%
div=a/b

# %% [markdown]
# variable decalaration in python

# %%
a=100
b=10
div=a/b
print(div)
# Out:
# 10.0

# %%
div=a%b

# %% [markdown]
# variable decalaration in python

# %%
from binascii import b2a_base64
a=120
b=4
div1=a%b
print(div1)
# Out:
# 0

# %%
squ=a*a

# %% [markdown]
# variable decalaration in python

# %%
a=50
squ=a*a
print(squ)
# Out:
# 2500

# %%
sroot=a**0.5

# %% [markdown]
# variable decalaration in python

# %%
a=4
sroot=a**0.5
print(sroot)
# Out:
# 2.0

# %% [markdown]
# **div of 2 sqaure num**

# %%
a=10
b=5
sum=(a*a)/(b*b)
print(sum)
# Out:
# 4.0
